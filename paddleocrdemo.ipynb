# %%
# !python3 -m pip install paddlepaddle-gpu
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.5/542.5 MB 2.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 10.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 11.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.4 MB/s eta 0:00:00
# ...

# %%
# !pip install "paddleocr>=2.0.1"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 465.7/465.7 kB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.3/908.3 kB 9.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.2/299.2 kB 9.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 21.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 40.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 MB 10.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 MB 10.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 99.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 113.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.6/239.6 kB 27.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 13.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
# !wget http://nz2.archieve.ubuntu.com/ubuntu/pool/main/o/openssl/libssl1.1_1.1.1f-1ubuntu2.19_amd64.deb

# !sudo dpkg -i libssl1.1_1.1.1f-ubuntu2.19_amd64.deb
# Out:
# --2023-11-16 12:09:15--  http://nz2.archieve.ubuntu.com/ubuntu/pool/main/o/openssl/libssl1.1_1.1.1f-1ubuntu2.19_amd64.deb
# Resolving nz2.archieve.ubuntu.com (nz2.archieve.ubuntu.com)... failed: Name or service not known.
# wget: unable to resolve host address ‘nz2.archieve.ubuntu.com’
# dpkg: error: cannot access archive 'libssl1.1_1.1.1f-ubuntu2.19_amd64.deb': No such file or directory

# %%
from paddleocr import PaddleOCR,draw_ocr
ocr=PaddleOCR(use_angle_cls=True,lang='en')
# Out:
# download https://paddleocr.bj.bcebos.com/PP-OCRv3/english/en_PP-OCRv3_det_infer.tar to /root/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer/en_PP-OCRv3_det_infer.tar
# 100%|██████████| 4.00M/4.00M [00:14<00:00, 268kiB/s]
# download https://paddleocr.bj.bcebos.com/PP-OCRv4/english/en_PP-OCRv4_rec_infer.tar to /root/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer/en_PP-OCRv4_rec_infer.tar
# 100%|██████████| 10.2M/10.2M [00:11<00:00, 926kiB/s]
# download https://paddleocr.bj.bcebos.com/dygraph_v2.0/ch/ch_ppocr_mobile_v2.0_cls_infer.tar to /root/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer/ch_ppocr_mobile_v2.0_cls_infer.tar
# 100%|██████████| 2.19M/2.19M [00:14<00:00, 147kiB/s]
# ...

# %%
from google.colab.patches import cv2_imshow
import cv2

# %%
img_path='/content/invoice.png'
img=cv2.imread(img_path, cv2.IMREAD_UNCHANGED)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1208x1392>

# %%
img
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
#run the ocr method on the ocr model
result=ocr.ocr(img_path)
# Out:
# [2023/11/16 12:24:34] ppocr DEBUG: dt_boxes num : 39, elapsed : 8.037229299545288
# [2023/11/16 12:24:34] ppocr DEBUG: cls num  : 39, elapsed : 0.11532258987426758
# [2023/11/16 12:24:34] ppocr DEBUG: rec_res num  : 39, elapsed : 0.2549581527709961

# %%
result
# Out:
# [[[[[135.0, 64.0], [417.0, 64.0], [417.0, 115.0], [135.0, 115.0]],
#    ('INVOICE', 0.9965866208076477)],
#   [[[129.0, 231.0], [405.0, 232.0], [405.0, 257.0], [129.0, 255.0]],
#    ('Your name/business name.', 0.9830144047737122)],
#   [[[129.0, 283.0], [269.0, 283.0], [269.0, 307.0], [129.0, 307.0]],
#    ('Your address', 0.9999144673347473)],
#   [[[131.0, 334.0], [337.0, 334.0], [337.0, 358.0], [131.0, 358.0]],
#    ('Your phone number.', 0.9803654551506042)],
#   [[[131.0, 383.0], [241.0, 383.0], [241.0, 407.0], [131.0, 407.0]],
#    ('Your email', 0.9952842593193054)],
#   [[[129.0, 493.0], [202.0, 496.0], [201.0, 522.0], [127.0, 519.0]],
#    ('Bill to:', 0.9966143369674683)],
#   [[[601.0, 496.0], [890.0, 496.0], [890.0, 516.0], [601.0, 516.0]],
#    ('Invoice number: ########', 0.9822051525115967)],
#   [[[134.0, 548.0], [418.0, 548.0], [418.0, 568.0], [134.0, 568.0]],
#    ('Buyer name/business name', 0.9986351132392883)],
# ...

# %%
len(result[0])
for res in result:
  print(res[0][1])
#text with confidence score
# Out:
# ('INVOICE', 0.9965866208076477)
